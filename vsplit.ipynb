# %%
import ffmpeg_split as fsp

# %%
fsp.split_by_seconds(filename='/workspaces/video-splitter/1UGD2DOA001.mpg', video_length=48, split_length=5)
# Out:
# About to run: ffmpeg -i /workspaces/video-splitter/1UGD2DOA001.mpg -vcodec copy -acodec copy -ss 0 -t 5 /workspaces/video-splitter/1UGD2DOA001-1-of-10.mpg
# About to run: ffmpeg -i /workspaces/video-splitter/1UGD2DOA001.mpg -vcodec copy -acodec copy -ss 5 -t 5 /workspaces/video-splitter/1UGD2DOA001-2-of-10.mpg
# About to run: ffmpeg -i /workspaces/video-splitter/1UGD2DOA001.mpg -vcodec copy -acodec copy -ss 10 -t 5 /workspaces/video-splitter/1UGD2DOA001-3-of-10.mpg
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...
